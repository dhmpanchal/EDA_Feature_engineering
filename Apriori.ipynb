# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/training_data.csv')
df.head()
# Out:
#    order_date                                        product_ids  \
# 0  2020-03-01  20169|20170|20172|21877|30331|31628|31800|3180...
# 1  2020-02-27  2650|5674|5931|6568|15899|16045|18148|19720|22...
# 2  2020-02-21  3507|3509|4478|5159|6180|6243|6530|7131|7133|8...
# 3  2020-02-21                                        30574|31077
# 4  2020-02-27    27173|31281|32472|35994|40350|40351|40425|40677
#
#                                        product_title
# 0  ABC Preschool Activity Book |123 Preschool Lea...
# 1  Hopping Easter Chick|* Cadbury Freddo Bars 5 P...
# 2  Drools 850g Biscuit Mix\t\t|Crunchy Peanut But...
# 3  Astonish Floor Cleaner Orchid Blossom 1L|Aston...
# 4  Zoflora Antibacterial Concentrated Disinfectan...

# %%
df.isnull()
# Out:
#        order_date  product_ids  product_title
# 0           False        False          False
# 1           False        False          False
# 2           False        False          False
# 3           False        False          False
# 4           False        False          False
# ...           ...          ...            ...
# 10995       False        False          False
# 10996       False        False          False
# 10997       False        False          False
# 10998       False        False          False
# 10999       False        False          False
#
# [11000 rows x 3 columns]

# %%
from pandas.core.missing import clean_fill_method
clean_data = []

for item in df.values.tolist():
  clean_data.append(str(item[2]).split('|'))

# %%
from apyori import apriori
rules = apriori(clean_data, min_support=0.07, min_confidence=0.35,min_lift=3,min_length=2)

# %%
list(rules)
# Out:
# []
